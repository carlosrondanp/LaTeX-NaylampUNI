# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diccionario = {'Nombres': ['ronald','Carlos','Jesús'],
              'Universidad': ['UNI','UNMSM','PUCP'],
              'Edades': [20,21,22]}

# %%
dataframe = pd.DataFrame(diccionario)

# %%
dataframe.to_latex('tabla.tex', caption='hola a todos', index = False)
